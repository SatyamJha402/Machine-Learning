# %%
import pandas as pd
import numpy as np
import  sklearn.linear_model

# %%
df = pd.DataFrame([[1,2,3],[4,8,6],[8,8,9]], index=["A","B","C"], columns=["P","Q","R"])

# %%
 df.head()
#df.head(2)
#df.tail()
# Out:
#    P  Q  R
# A  1  2  3
# B  4  8  6
# C  8  8  9

# %%
df.index.tolist()
#df.index
# Out:
# ['A', 'B', 'C']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, A to C
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   P       3 non-null      int64
#  1   Q       3 non-null      int64
#  2   R       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#               P         Q    R
# count  3.000000  3.000000  3.0
# mean   4.333333  6.000000  6.0
# std    3.511885  3.464102  3.0
# min    1.000000  2.000000  3.0
# 25%    2.500000  5.000000  4.5
# 50%    4.000000  8.000000  6.0
# 75%    6.000000  8.000000  7.5
# max    8.000000  8.000000  9.0

# %%
# df["P"].nunique()
df.shape
df.size
# Out:
# 9

# %%
 #pd.read_csv(C:\Users\satya\Documents\pandas\coffee.csv")

# %%
coffee = pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/master/warmup-data/coffee.csv")
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.tail(1)
# Out:
#        Day Coffee Type  Units Sold
# 13  Sunday       Latte          35

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
 newdf = pd.DataFrame(np.random.rand(334,5))
newdf
# Out:
#             0         1         2         3         4
# 0    0.131838  0.189009  0.768445  0.401497  0.213823
# 1    0.367426  0.725210  0.221318  0.676274  0.464310
# 2    0.015114  0.801426  0.432067  0.812381  0.419955
# 3    0.666303  0.136830  0.492251  0.431646  0.396775
# 4    0.093819  0.032981  0.789048  0.269730  0.590699
# ..        ...       ...       ...       ...       ...
# 329  0.555918  0.087747  0.835045  0.762972  0.028256
# 330  0.029318  0.078156  0.856775  0.685639  0.237762
# 331  0.703040  0.065292  0.875573  0.573316  0.177696
# 332  0.448716  0.311328  0.037834  0.478158  0.448864
# 333  0.720415  0.717338  0.853135  0.705275  0.897450
#
# [334 rows x 5 columns]

# %%
newdf = pd.DataFrame(np.random.rand(334,5), index=np.arange(1, 668, 2))
newdf
# Out:
#             0         1         2         3         4
# 1    0.795289  0.779988  0.556551  0.355279  0.750810
# 3    0.465566  0.067664  0.952550  0.495957  0.506636
# 5    0.329079  0.947634  0.810042  0.898362  0.012453
# 7    0.911420  0.055976  0.191138  0.878021  0.548952
# 9    0.805929  0.059497  0.386846  0.514264  0.831353
# ..        ...       ...       ...       ...       ...
# 659  0.328314  0.644618  0.088733  0.385241  0.621794
# 661  0.642409  0.876240  0.414894  0.167801  0.123969
# 663  0.621649  0.630628  0.894527  0.241080  0.816925
# 665  0.131151  0.072620  0.468419  0.690867  0.367714
# 667  0.567519  0.500675  0.133452  0.732643  0.751781
#
# [334 rows x 5 columns]

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.519053    0.458703    0.506042    0.514205    0.469146
# std      0.286248    0.281825    0.284967    0.290145    0.291011
# min      0.004557    0.004793    0.001455    0.003517    0.000560
# 25%      0.282003    0.227960    0.252109    0.274841    0.216460
# 50%      0.531137    0.434589    0.490728    0.507752    0.459084
# 75%      0.763736    0.696915    0.751502    0.768295    0.703979
# max      0.998246    0.998166    0.997448    0.993809    0.994435

# %%
df.dtypes
# Out:
# P    int64
# Q    int64
# R    int64
# dtype: object

# %%
df.head()
# Out:
#    P  Q  R
# A  1  2  3
# B  4  8  6
# C  8  8  9

# %%
df.index
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.columns
# Out:
# Index(['P', 'Q', 'R'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[1, 2, 3],
#        [4, 8, 6],
#        [8, 8, 9]], dtype=int64)

# %%
df.T
# Out:
#    A  B  C
# P  1  4  8
# Q  2  8  8
# R  3  6  9

# %%
df.dtypes
# Out:
# P    int64
# Q    int64
# R    int64
# dtype: object

# %%
print(df)
# Out:
#    P  Q  R
# A  1  2  3
# B  4  8  6
# C  8  8  9

# %%
df.sort_index(axis = 0, ascending = False)
# Out:
#    P  Q  R
# C  8  8  9
# B  4  8  6
# A  1  2  3

# %%
df.sort_index(axis=1, ascending = False)
# Out:
#    R  Q  P
# A  3  2  1
# B  6  8  4
# C  9  8  8

# %%
df.head()
# Out:
#    P  Q  R
# A  1  2  3
# B  4  8  6
# C  8  8  9

# %%
cof = pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/master/warmup-data/coffee.csv")

# %%
# cof.to_excel
cof.to_parquet
# Out:
# <bound method DataFrame.to_parquet of           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35>

# %%
coffee.head(2)
# Out:
#       Day Coffee Type  Units Sold
# 0  Monday    Espresso          25
# 1  Monday       Latte          15

# %%
coffee.sample(4, random_state=2)
# Out:
#           Day Coffee Type  Units Sold
# 11   Saturday       Latte          35
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 0      Monday    Espresso          25

# %%
#coffee.loc[5:]
#coffee.loc[[4,6]]
#coffee.loc[4]
#coffee.loc[4:6]
#coffee.loc[5:8, ["Day", "Units Sold"]]
#coffee.loc[:,["Day"]]
#coffee.iloc[:,[0,1,2]]

# %%
#coffee.index = coffee.Day
#coffee.index = coffee["Day"]
#coffee.loc["Monday"]
coffee.set_index("price", inplace=True)
coffee.head()
# Out:
#              Day Coffee Type  Units Sold  new_price  revenue
# price
# 50        Monday    Espresso          10       3.99      500
# 50        Monday       Latte          10      58.99      500
# 50       Tuesday    Espresso          10       3.99     1500
# 50       Tuesday       Latte          10      58.99     1000
# 50     Wednesday    Espresso          35       3.99     1750

# %%
coffee.loc[0:3,"Units Sold"] = 10

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  new_price  price  revenue
# 0     Monday    Espresso          10       3.99     50      500
# 1     Monday       Latte          10      58.99     50      500
# 2    Tuesday    Espresso          10       3.99     50     1500
# 3    Tuesday       Latte          10      58.99     50     1000
# 4  Wednesday    Espresso          35       3.99     50     1750

# %%
coffee.at[0,"Units Sold"]
# Out:
# 10

# %%
#coffee.sort_values("Units Sold")
coffee.sort_values("Units Sold", ascending = False)
# Out:
#           Day Coffee Type  Units Sold  new_price  price  revenue
# 8      Friday    Espresso          45       3.99     50     2250
# 10   Saturday    Espresso          45       3.99     50     2250
# 12     Sunday    Espresso          45       3.99     50     2250
# 6    Thursday    Espresso          40       3.99     50     2000
# 4   Wednesday    Espresso          35       3.99     50     1750
# 9      Friday       Latte          35      58.99     50     1750
# 11   Saturday       Latte          35      58.99     50     1750
# 13     Sunday       Latte          35      58.99     50     1750
# 7    Thursday       Latte          30      58.99     50     1500
# 5   Wednesday       Latte          25      58.99     50     1250
# 0      Monday    Espresso          10       3.99     50      500
# 1      Monday       Latte          10      58.99     50      500
# 2     Tuesday    Espresso          10       3.99     50     1500
# ...

# %%
bios = pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/master/data/bios.csv")
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
bios.loc[bios["height_cm"]>220]
# Out:
#         athlete_id             name   born_date       born_city  \
# 5673          5696   Gunther Behnke  1963-01-19      Leverkusen
# 5781          5804   Tommy Burleson  1952-02-24       Crossnore
# 6978          7013  Arvydas Sabonis  1964-12-19          Kaunas
# 89070        89782         Yao Ming  1980-09-12  Xuhui District
# 89075        89787   Roberto Dueñas  1975-11-01          Madrid
# 120266      122147     Zhang Zhaoxu  1987-11-18         Binzhou
#
#                 born_region born_country                         NOC  \
# 5673    Nordrhein-Westfalen          GER                     Germany
# 5781         North Carolina          USA               United States
# 6978                 Kaunas          LTU      Lithuania Soviet Union
# 89070              Shanghai          CHN  People's Republic of China
# 89075                Madrid          ESP                       Spain
# 120266             Shandong          CHN  People's Republic of China
#
# ...

# %%
bios.loc[bios["height_cm"]>220, ["name"]]
# Out:
#                    name
# 5673     Gunther Behnke
# 5781     Tommy Burleson
# 6978    Arvydas Sabonis
# 89070          Yao Ming
# 89075    Roberto Dueñas
# 120266     Zhang Zhaoxu

# %%
bios[bios["height_cm"]>220]
# Out:
#         athlete_id             name   born_date       born_city  \
# 5673          5696   Gunther Behnke  1963-01-19      Leverkusen
# 5781          5804   Tommy Burleson  1952-02-24       Crossnore
# 6978          7013  Arvydas Sabonis  1964-12-19          Kaunas
# 89070        89782         Yao Ming  1980-09-12  Xuhui District
# 89075        89787   Roberto Dueñas  1975-11-01          Madrid
# 120266      122147     Zhang Zhaoxu  1987-11-18         Binzhou
#
#                 born_region born_country                         NOC  \
# 5673    Nordrhein-Westfalen          GER                     Germany
# 5781         North Carolina          USA               United States
# 6978                 Kaunas          LTU      Lithuania Soviet Union
# 89070              Shanghai          CHN  People's Republic of China
# 89075                Madrid          ESP                       Spain
# 120266             Shandong          CHN  People's Republic of China
#
# ...

# %%
bios[(bios["height_cm"]>220) & (bios["born_country"]== "CHN")]
# Out:
#         athlete_id          name   born_date       born_city born_region  \
# 89070        89782      Yao Ming  1980-09-12  Xuhui District    Shanghai
# 120266      122147  Zhang Zhaoxu  1987-11-18         Binzhou    Shandong
#
#        born_country                         NOC  height_cm  weight_kg  \
# 89070           CHN  People's Republic of China      226.0      141.0
# 120266          CHN  People's Republic of China      221.0      110.0
#
#        died_date
# 89070        NaN
# 120266       NaN

# %%
bios[bios["name"].str.contains("Shaq|patrik", case=False)]
# Out:
#         athlete_id                            name   born_date  \
# 6722          6755                Shaquille O'Neal  1972-03-06
# 26996        27193                Patrik Andersson  1971-08-18
# 31722        31961                    Patrik Ćavar  1971-03-24
# 32473        32717              Patrik Liljestrand  1966-01-25
# 43829        44168                 Patrik de Laval  1886-10-14
# 46269        46616                   Ulla Patrikka  1946-04-10
# 52619        52994                Patrik Johansson  1963-09-20
# 61942        62397                   Patrik Hrdina  1967-05-15
# 62873        63340                   Patrik Pollák  1972-09-06
# 73858        74428               Syed Meshaq Rizvi  1962-01-23
# 75503        76081                    Patrik Bodén  1967-06-30
# 75761        76343                  Patrik Ohlsson  1889-10-28
# 75798        76381                  Patrik Sjöberg  1965-01-05
# 75811        76394                 Patrik Strenius  1972-03-06
# ...

# %%
bios[bios["born_country"].isin(["USA"]) & (bios["name"].str.startswith("Shaq"))]
# Out:
#       athlete_id              name   born_date born_city born_region  \
# 6722        6755  Shaquille O'Neal  1972-03-06    Newark  New Jersey
#
#      born_country            NOC  height_cm  weight_kg died_date
# 6722          USA  United States      216.0      137.0       NaN

# %%
bios[bios["born_country"].isin(["USA", "GBR"])]
# Out:
#         athlete_id               name   born_date      born_city  born_region  \
# 4                5       Albert Canet  1878-04-17     Wandsworth      England
# 37              38    Helen Aitchison  1881-12-06     Sunderland      England
# 38              39  Geraldine Beamish  1883-06-23    Forest Gate      England
# 39              40       Dora Boothby  1881-08-02       Finchley      England
# 40              41     Julie Bradbury  1967-02-12         Oxford      England
# ...            ...                ...         ...            ...          ...
# 145445      149168     Kristen Santos  1994-11-02      Fairfield  Connecticut
# 145446      149169   Corinne Stoddard  2001-08-15        Seattle   Washington
# 145454      149180      Anna Hoffmann  2000-03-28        Madison    Wisconsin
# 145457      149183     Alix Wilkinson  2000-08-02  Mammoth Lakes   California
# 145468      149195  Justin Abdelkader  1987-02-25       Muskegon     Michigan
#
# ...

# %%
bios.query('NOC == "India" and born_city =="Delhi"')
# Out:
#         athlete_id                       name   born_date born_city  \
# 19047        19181            Michael Gateley  1904-06-13     Delhi
# 19053        19187                Arthur Hind  1904-10-20     Delhi
# 19080        19214  Mirza Nasir-ud-Din Masood  1906-04-23     Delhi
# 19102        19236             Jaswant Rajput  1926-01-01     Delhi
# 19146        19281                Gindi Singh  1940-08-03     Delhi
# 34106        34370             Narinder Singh  1969-05-28     Delhi
# 58278        58692               Parkash Gian  1937-06-19     Delhi
# 58300        58714                  Prem Nath  1951-07-01     Delhi
# 58321        58736                Malwa Singh  1946-03-20     Delhi
# 70911        71443                Surat Singh  1930-08-22     Delhi
# 80939        81590             Shailaja Kumar  1967-01-17     Delhi
# 106916      108030                Sujeet Maan  1978-12-15     Delhi
# 107001      108119                 Anuj Kumar  1980-08-05     Delhi
# ...

# %%
coffee["price"]=5
coffee.head()
# Out:
#              Day Coffee Type  Units Sold  new_price  revenue  price
# price
# 50        Monday    Espresso          10       3.99      500      5
# 50        Monday       Latte          10      58.99      500      5
# 50       Tuesday    Espresso          10       3.99     1500      5
# 50       Tuesday       Latte          10      58.99     1000      5
# 50     Wednesday    Espresso          35       3.99     1750      5

# %%
coffee['new_price'] = np.where(coffee["Coffee Type"]=="Espresso", 3.99, 58.99)

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price  new_price
# 0     Monday    Espresso          10   5.99       3.99
# 1     Monday       Latte          10   5.99      58.99
# 2    Tuesday    Espresso          30   5.99       3.99
# 3    Tuesday       Latte          20   5.99      58.99
# 4  Wednesday    Espresso          35   5.99       3.99

# %%
coffee.drop([0,1])
#cpffee.drop(3)
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 2     Tuesday    Espresso          30   5.99       3.99
# 3     Tuesday       Latte          20   5.99      58.99
# 4   Wednesday    Espresso          35   5.99       3.99
# 5   Wednesday       Latte          25   5.99      58.99
# 6    Thursday    Espresso          40   5.99       3.99
# 7    Thursday       Latte          30   5.99      58.99
# 8      Friday    Espresso          45   5.99       3.99
# 9      Friday       Latte          35   5.99      58.99
# 10   Saturday    Espresso          45   5.99       3.99
# 11   Saturday       Latte          35   5.99      58.99
# 12     Sunday    Espresso          45   5.99       3.99
# 13     Sunday       Latte          35   5.99      58.99

# %%
coffee.drop(columns=["price"])
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          10       3.99
# 1      Monday       Latte          10      58.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20      58.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25      58.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30      58.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35      58.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35      58.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35      58.99

# %% [markdown]
# <h3>To replace the column or row from the original one</h3>

# %%
coffee.drop(columns=["price"], inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          10       3.99
# 1      Monday       Latte          10      58.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20      58.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25      58.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30      58.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35      58.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35      58.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35      58.99

# %%
coffee_new=coffee

# %%
coffee_new['price'] = 50

# %%
#coffee
#coffee_new

# %%
# coffee = coffee[["Day", "Units Sold"]]
# coffee

# %%
coffee["revenue"] = coffee["Units Sold"]*coffee["price"]

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  price  revenue
# 0      Monday    Espresso          10       3.99     50      500
# 1      Monday       Latte          10      58.99     50      500
# 2     Tuesday    Espresso          30       3.99     50     1500
# 3     Tuesday       Latte          20      58.99     50     1000
# 4   Wednesday    Espresso          35       3.99     50     1750
# 5   Wednesday       Latte          25      58.99     50     1250
# 6    Thursday    Espresso          40       3.99     50     2000
# 7    Thursday       Latte          30      58.99     50     1500
# 8      Friday    Espresso          45       3.99     50     2250
# 9      Friday       Latte          35      58.99     50     1750
# 10   Saturday    Espresso          45       3.99     50     2250
# 11   Saturday       Latte          35      58.99     50     1750
# 12     Sunday    Espresso          45       3.99     50     2250
# ...

# %%
coffee.rename(columns={"new_price":"discount"})
# Out:
#           Day Coffee Type  Units Sold  discount  price  revenue
# 0      Monday    Espresso          10      3.99     50      500
# 1      Monday       Latte          10     58.99     50      500
# 2     Tuesday    Espresso          30      3.99     50     1500
# 3     Tuesday       Latte          20     58.99     50     1000
# 4   Wednesday    Espresso          35      3.99     50     1750
# 5   Wednesday       Latte          25     58.99     50     1250
# 6    Thursday    Espresso          40      3.99     50     2000
# 7    Thursday       Latte          30     58.99     50     1500
# 8      Friday    Espresso          45      3.99     50     2250
# 9      Friday       Latte          35     58.99     50     1750
# 10   Saturday    Espresso          45      3.99     50     2250
# 11   Saturday       Latte          35     58.99     50     1750
# 12     Sunday    Espresso          45      3.99     50     2250
# 13     Sunday       Latte          35     58.99     50     1750

# %%
bios_new=bios.copy()

# %%
bios_new["first_name"] = bios_new["name"].str.split(" ").str[0]

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...
